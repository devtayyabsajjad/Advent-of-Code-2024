# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "source": [
        "# **Before ruuning the code update the path**"
      ],
      "metadata": {
        "id": "eySSbqnpPfXP"
      }
    },
    {
      "cell_type": "markdown",
      "source": [
        "# Day 2: Red-Nosed Reports\n",
        "\n",
        "### Problem Statement\n",
        "\n",
        "You are tasked with analyzing data from the Red-Nosed reactor. Each line of the input data is a \"report\" consisting of levels represented as numbers separated by spaces. A report is considered **safe** if it satisfies **both** of the following rules:\n",
        "\n",
        "1. The levels are either **all increasing** or **all decreasing**.\n",
        "2. Any two adjacent levels differ by at least **1** and at most **3**.\n",
        "\n",
        "### Example Input\n",
        "\n"
      ],
      "metadata": {
        "id": "qBBFUnbRw9CC"
      }
    },
    {
      "cell_type": "markdown",
      "source": [
        "\n",
        "### Safety Analysis\n",
        "\n",
        "- **Safe Reports:**\n",
        "  - `7 6 4 2 1`: Levels are decreasing by 1 or 2.\n",
        "  - `1 3 6 7 9`: Levels are increasing by 1, 2, or 3.\n",
        "\n",
        "- **Unsafe Reports:**\n",
        "  - `1 2 7 8 9`: Increase of 5 between `2` and `7`.\n",
        "  - `9 7 6 2 1`: Decrease of 4 between `6` and `2`.\n",
        "  - `1 3 2 4 5`: Both increasing and decreasing transitions exist.\n",
        "  - `8 6 4 4 1`: Contains a level that neither increases nor decreases (`4 4`).\n",
        "\n",
        "**In this example, 2 reports are safe.**\n",
        "\n"
      ],
      "metadata": {
        "id": "y4JdnlqrxLvx"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "def is_report_safe(report):\n",
        "    \"\"\"\n",
        "    Determine if a report is safe based on two criteria:\n",
        "    1. Levels are either all increasing or all decreasing\n",
        "    2. Adjacent levels differ by at least 1 and at most 3\n",
        "    \"\"\"\n",
        "    levels = list(map(int, report.split()))\n",
        "    if not levels:\n",
        "        return False\n",
        "    is_increasing = all(levels[i+1] > levels[i] for i in range(len(levels) - 1))\n",
        "    is_decreasing = all(levels[i] > levels[i+1] for i in range(len(levels) - 1))\n",
        "    if not (is_increasing or is_decreasing):\n",
        "        return False\n",
        "    for i in range(len(levels) - 1):\n",
        "        diff = abs(levels[i+1] - levels[i])\n",
        "        if diff < 1 or diff > 3:\n",
        "            return False\n",
        "    return True\n",
        "\n",
        "def analyze_safety_reports(input_data):\n",
        "    \"\"\"\n",
        "    Analyze the safety of all reports in the input data\n",
        "    \"\"\"\n",
        "    reports = input_data.strip().split('\\n')\n",
        "\n",
        "    safe_reports = sum(1 for report in reports if is_report_safe(report))\n",
        "\n",
        "    return safe_reports\n",
        "try:\n",
        "    with open('/content/Input.txt', 'r') as file:\n",
        "        input_data = file.read()\n",
        "    safe_report_count = analyze_safety_reports(input_data)\n",
        "    print(f\"Number of safe reports: {safe_report_count}\")\n",
        "except FileNotFoundError:\n",
        "    print(\"Error: The file '/content/Input.txt' was not found.\")\n",
        "\n",
        "\n"
      ],
      "metadata": {
        "id": "JJH04Faq7j_5",
        "outputId": "13954c60-d156-40b5-e636-b07f9d696488",
        "colab": {
          "base_uri": "https://localhost:8080/"
        }
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Number of safe reports: 442\n"
          ]
        }
      ]
    },
    {
      "cell_type": "markdown",
      "source": [
        "I am wrote a function `is_report_safe(report)` to check if a report is safe based on two conditions:\n",
        "\n",
        "1. Levels are either strictly increasing or strictly decreasing.\n",
        "2. The difference between adjacent levels is between 1 and 3.\n",
        "\n",
        "The report is split into a list of levels, and you check if the sequence follows these rules. In `analyze_safety_reports(input_data)`, you read input data, split it into reports, and count how many are safe by calling `is_report_safe()`. You handle missing files with a `try-except` block to avoid errors. Finally, the safe report count is printed.\n"
      ],
      "metadata": {
        "id": "8jPrc_4oQM6s"
      }
    },
    {
      "cell_type": "markdown",
      "source": [
        "##  Part Two\n",
        "\n",
        "The engineers are surprised by the low number of safe reports until they realize they forgot to tell you about the Problem Dampener.\n",
        "\n",
        "The Problem Dampener is a reactor-mounted module that lets the reactor safety systems tolerate a single bad level in what would otherwise be a safe report. It's like the bad level never happened!\n",
        "\n",
        "Now, the same rules apply as before, except if removing a single level from an unsafe report would make it safe, the report instead counts as safe.\n",
        "\n",
        "### Example Update:\n",
        "\n",
        "More of the above example's reports are now safe:\n",
        "\n",
        "1. **7 6 4 2 1**: Safe without removing any level.\n",
        "2. **1 2 7 8 9**: Unsafe regardless of which level is removed.\n",
        "3. **9 7 6 2 1**: Unsafe regardless of which level is removed.\n",
        "4. **1 3 2 4 5**: Safe by removing the second level, 3.\n",
        "5. **8 6 4 4 1**: Safe by removing the third level, 4.\n",
        "6. **1 3 6 7 9**: Safe without removing any level.\n",
        "\n",
        "Thanks to the Problem Dampener, 4 reports are actually safe!"
      ],
      "metadata": {
        "id": "1UQU-9PW-QPw"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "def is_report_safe(report):\n",
        "    \"\"\"\n",
        "    Check if the report is safe based on the two conditions:\n",
        "    1. The levels are either strictly increasing or strictly decreasing.\n",
        "    2. The difference between adjacent levels is between 1 and 3.\n",
        "    \"\"\"\n",
        "    levels = list(map(int, report.split()))\n",
        "    is_increasing = all(levels[i+1] > levels[i] for i in range(len(levels) - 1))\n",
        "    is_decreasing = all(levels[i] > levels[i+1] for i in range(len(levels) - 1))\n",
        "    if not (is_increasing or is_decreasing):\n",
        "        return False\n",
        "\n",
        "    for i in range(len(levels) - 1):\n",
        "        diff = abs(levels[i+1] - levels[i])\n",
        "        if diff < 1 or diff > 3:\n",
        "            return False\n",
        "\n",
        "    return True\n",
        "\n",
        "def is_report_safe_with_dampener(report):\n",
        "    \"\"\"\n",
        "    Check if the report can be made safe with the Problem Dampener\n",
        "    (by removing at most one level).\n",
        "    \"\"\"\n",
        "    levels = list(map(int, report.split()))\n",
        "    if is_report_safe(report):\n",
        "        return True\n",
        "    for i in range(len(levels)):\n",
        "        modified_report = levels[:i] + levels[i+1:]\n",
        "        if is_report_safe(' '.join(map(str, modified_report))):\n",
        "            return True\n",
        "    return False\n",
        "\n",
        "def analyze_safety_reports(input_data, with_dampener=False):\n",
        "    \"\"\"\n",
        "    Analyze the safety of all reports in the input data.\n",
        "    If with_dampener is True, consider reports that can be made safe by removing one level.\n",
        "    \"\"\"\n",
        "    reports = input_data.strip().split('\\n')\n",
        "    if with_dampener:\n",
        "        safe_reports = sum(1 for report in reports if is_report_safe_with_dampener(report))\n",
        "    else:\n",
        "        safe_reports = sum(1 for report in reports if is_report_safe(report))\n",
        "    return safe_reports\n",
        "try:\n",
        "    with open('/content/Input.txt', 'r') as file:\n",
        "        input_data = file.read()\n",
        "    safe_report_count_part1 = analyze_safety_reports(input_data, with_dampener=False)\n",
        "    print(f\"Number of safe reports (Part 1): {safe_report_count_part1}\")\n",
        "    safe_report_count_part2 = analyze_safety_reports(input_data, with_dampener=True)\n",
        "    print(f\"Number of safe reports (Part 2): {safe_report_count_part2}\")\n",
        "except FileNotFoundError:\n",
        "    print(\"Error: The file '/content/Input.txt' was not found.\")\n"
      ],
      "metadata": {
        "id": "WE6hWE5o77I4",
        "outputId": "0aeeca54-6618-4cbc-eea0-161c758570cc",
        "colab": {
          "base_uri": "https://localhost:8080/"
        }
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Number of safe reports (Part 1): 442\n",
            "Number of safe reports (Part 2): 493\n"
          ]
        }
      ]
    },
    {
      "cell_type": "markdown",
      "source": [
        "You wrote two functions to analyze safety reports:\n",
        "\n",
        "1. `is_report_safe(report)`: Checks if a report is safe based on two conditions:\n",
        "    - The levels are either strictly increasing or strictly decreasing.\n",
        "    - The difference between adjacent levels is between 1 and 3.\n",
        "\n",
        "2. `is_report_safe_with_dampener(report)`: Checks if a report can be made safe by removing at most one level (Problem Dampener).\n",
        "\n",
        "In `analyze_safety_reports(input_data, with_dampener=False)`, you read the input data, split it into reports, and count how many reports are safe. If `with_dampener` is `True`, it considers reports that can be made safe by removing a level.\n",
        "\n",
        "The solution also handles missing files using a `try-except` block to avoid errors and prints the number of safe reports for both parts of the puzzle.\n"
      ],
      "metadata": {
        "id": "snFm22WHQjJC"
      }
    }
  ],
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "display_name": "Python 3",
      "name": "python3"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 0
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 102
#       1 {
#       2   "cells": [
#       3     {
#       4       "cell_type": "markdown",
#       5       "source": [
#       6         "# **Before ruuning the code update the path**"
#       7       ],
#       8       "metadata": {
#       9         "id": "eySSbqnpPfXP"
#      10       }
#      11     },
#      12     {
#      13       "cell_type": "markdown",
#      14       "source": [
#      15         "# Day 2: Red-Nosed Reports\n",
#      16         "\n",
#      17         "### Problem Statement\n",
#      18         "\n",
#      19         "You are tasked with analyzing data from the Red-Nosed reactor. Each line of the input data is a \"report\" consisting of levels represented as numbers separated by spaces. A report is considered **safe** if it satisfies **both** of the following rules:\n",
#      20         "\n",
#      21         "1. The levels are either **all increasing** or **all decreasing**.\n",
#      22         "2. Any two adjacent levels differ by at least **1** and at most **3**.\n",
#      23         "\n",
#      24         "### Example Input\n",
#      25         "\n"
#      26       ],
#      27       "metadata": {
#      28         "id": "qBBFUnbRw9CC"
#      29       }
#      30     },
#      31     {
#      32       "cell_type": "markdown",
#      33       "source": [
#      34         "\n",
#      35         "### Safety Analysis\n",
#      36         "\n",
#      37         "- **Safe Reports:**\n",
#      38         "  - `7 6 4 2 1`: Levels are decreasing by 1 or 2.\n",
#      39         "  - `1 3 6 7 9`: Levels are increasing by 1, 2, or 3.\n",
#      40         "\n",
#      41         "- **Unsafe Reports:**\n",
#      42         "  - `1 2 7 8 9`: Increase of 5 between `2` and `7`.\n",
#      43         "  - `9 7 6 2 1`: Decrease of 4 between `6` and `2`.\n",
#      44         "  - `1 3 2 4 5`: Both increasing and decreasing transitions exist.\n",
#      45         "  - `8 6 4 4 1`: Contains a level that neither increases nor decreases (`4 4`).\n",
#      46         "\n",
#      47         "**In this example, 2 reports are safe.**\n",
#      48         "\n"
#      49       ],
#      50       "metadata": {
#      51         "id": "y4JdnlqrxLvx"
#      52       }
#      53     },
#      54     {
#      55       "cell_type": "code",
#      56       "source": [
#      57         "def is_report_safe(report):\n",
#      58         "    \"\"\"\n",
#      59         "    Determine if a report is safe based on two criteria:\n",
#      60         "    1. Levels are either all increasing or all decreasing\n",
#      61         "    2. Adjacent levels differ by at least 1 and at most 3\n",
#      62         "    \"\"\"\n",
#      63         "    levels = list(map(int, report.split()))\n",
#      64         "    if not levels:\n",
#      65         "        return False\n",
#      66         "    is_increasing = all(levels[i+1] > levels[i] for i in range(len(levels) - 1))\n",
#      67         "    is_decreasing = all(levels[i] > levels[i+1] for i in range(len(levels) - 1))\n",
#      68         "    if not (is_increasing or is_decreasing):\n",
#      69         "        return False\n",
#      70         "    for i in range(len(levels) - 1):\n",
#      71         "        diff = abs(levels[i+1] - levels[i])\n",
#      72         "        if diff < 1 or diff > 3:\n",
#      73         "            return False\n",
#      74         "    return True\n",
#      75         "\n",
#      76         "def analyze_safety_reports(input_data):\n",
#      77         "    \"\"\"\n",
#      78         "    Analyze the safety of all reports in the input data\n",
#      79         "    \"\"\"\n",
#      80         "    reports = input_data.strip().split('\\n')\n",
#      81         "\n",
#      82         "    safe_reports = sum(1 for report in reports if is_report_safe(report))\n",
#      83         "\n",
#      84         "    return safe_reports\n",
#      85         "try:\n",
#      86         "    with open('/content/Input.txt', 'r') as file:\n",
#      87         "        input_data = file.read()\n",
#      88         "    safe_report_count = analyze_safety_reports(input_data)\n",
#      89         "    print(f\"Number of safe reports: {safe_report_count}\")\n",
#      90         "except FileNotFoundError:\n",
#      91         "    print(\"Error: The file '/content/Input.txt' was not found.\")\n",
#      92         "\n",
#      93         "\n"
#      94       ],
#      95       "metadata": {
#      96         "id": "JJH04Faq7j_5",
#      97         "outputId": "13954c60-d156-40b5-e636-b07f9d696488",
#      98         "colab": {
#      99           "base_uri": "https://localhost:8080/"
#     100         }
#     101       },
# --> 102       "execution_count": null,
#     103       "outputs": [
#     104         {
#     105           "output_type": "stream",
#     106           "name": "stdout",
#     107           "text": [
#     108             "Number of safe reports: 442\n"
#     109           ]
#     110         }
#     111       ]
#     112     },
#     113     {
#     114       "cell_type": "markdown",
#     115       "source": [
#     116         "I am wrote a function `is_report_safe(report)` to check if a report is safe based on two conditions:\n",
#     117         "\n",
#     118         "1. Levels are either strictly increasing or strictly decreasing.\n",
#     119         "2. The difference between adjacent levels is between 1 and 3.\n",
#     120         "\n",
#     121         "The report is split into a list of levels, and you check if the sequence follows these rules. In `analyze_safety_reports(input_data)`, you read input data, split it into reports, and count how many are safe by calling `is_report_safe()`. You handle missing files with a `try-except` block to avoid errors. Finally, the safe report count is printed.\n"
#     122       ],
#     123       "metadata": {
#     124         "id": "8jPrc_4oQM6s"
#     125       }
#     126     },
#     127     {
#     128       "cell_type": "markdown",
#     129       "source": [
#     130         "##  Part Two\n",
#     131         "\n",
#     132         "The engineers are surprised by the low number of safe reports until they realize they forgot to tell you about the Problem Dampener.\n",
#     133         "\n",
#     134         "The Problem Dampener is a reactor-mounted module that lets the reactor safety systems tolerate a single bad level in what would otherwise be a safe report. It's like the bad level never happened!\n",
#     135         "\n",
#     136         "Now, the same rules apply as before, except if removing a single level from an unsafe report would make it safe, the report instead counts as safe.\n",
#     137         "\n",
#     138         "### Example Update:\n",
#     139         "\n",
#     140         "More of the above example's reports are now safe:\n",
#     141         "\n",
#     142         "1. **7 6 4 2 1**: Safe without removing any level.\n",
#     143         "2. **1 2 7 8 9**: Unsafe regardless of which level is removed.\n",
#     144         "3. **9 7 6 2 1**: Unsafe regardless of which level is removed.\n",
#     145         "4. **1 3 2 4 5**: Safe by removing the second level, 3.\n",
#     146         "5. **8 6 4 4 1**: Safe by removing the third level, 4.\n",
#     147         "6. **1 3 6 7 9**: Safe without removing any level.\n",
#     148         "\n",
#     149         "Thanks to the Problem Dampener, 4 reports are actually safe!"
#     150       ],
#     151       "metadata": {
#     152         "id": "1UQU-9PW-QPw"
#     153       }
#     154     },
#     155     {
#     156       "cell_type": "code",
#     157       "source": [
#     158         "def is_report_safe(report):\n",
#     159         "    \"\"\"\n",
#     160         "    Check if the report is safe based on the two conditions:\n",
#     161         "    1. The levels are either strictly increasing or strictly decreasing.\n",
#     162         "    2. The difference between adjacent levels is between 1 and 3.\n",
#     163         "    \"\"\"\n",
#     164         "    levels = list(map(int, report.split()))\n",
#     165         "    is_increasing = all(levels[i+1] > levels[i] for i in range(len(levels) - 1))\n",
#     166         "    is_decreasing = all(levels[i] > levels[i+1] for i in range(len(levels) - 1))\n",
#     167         "    if not (is_increasing or is_decreasing):\n",
#     168         "        return False\n",
#     169         "\n",
#     170         "    for i in range(len(levels) - 1):\n",
#     171         "        diff = abs(levels[i+1] - levels[i])\n",
#     172         "        if diff < 1 or diff > 3:\n",
#     173         "            return False\n",
#     174         "\n",
#     175         "    return True\n",
#     176         "\n",
#     177         "def is_report_safe_with_dampener(report):\n",
#     178         "    \"\"\"\n",
#     179         "    Check if the report can be made safe with the Problem Dampener\n",
#     180         "    (by removing at most one level).\n",
#     181         "    \"\"\"\n",
#     182         "    levels = list(map(int, report.split()))\n",
#     183         "    if is_report_safe(report):\n",
#     184         "        return True\n",
#     185         "    for i in range(len(levels)):\n",
#     186         "        modified_report = levels[:i] + levels[i+1:]\n",
#     187         "        if is_report_safe(' '.join(map(str, modified_report))):\n",
#     188         "            return True\n",
#     189         "    return False\n",
#     190         "\n",
#     191         "def analyze_safety_reports(input_data, with_dampener=False):\n",
#     192         "    \"\"\"\n",
#     193         "    Analyze the safety of all reports in the input data.\n",
#     194         "    If with_dampener is True, consider reports that can be made safe by removing one level.\n",
#     195         "    \"\"\"\n",
#     196         "    reports = input_data.strip().split('\\n')\n",
#     197         "    if with_dampener:\n",
#     198         "        safe_reports = sum(1 for report in reports if is_report_safe_with_dampener(report))\n",
#     199         "    else:\n",
#     200         "        safe_reports = sum(1 for report in reports if is_report_safe(report))\n",
#     201         "    return safe_reports\n",
#     202         "try:\n",
#     203         "    with open('/content/Input.txt', 'r') as file:\n",
#     204         "        input_data = file.read()\n",
#     205         "    safe_report_count_part1 = analyze_safety_reports(input_data, with_dampener=False)\n",
#     206         "    print(f\"Number of safe reports (Part 1): {safe_report_count_part1}\")\n",
#     207         "    safe_report_count_part2 = analyze_safety_reports(input_data, with_dampener=True)\n",
#     208         "    print(f\"Number of safe reports (Part 2): {safe_report_count_part2}\")\n",
#     209         "except FileNotFoundError:\n",
#     210         "    print(\"Error: The file '/content/Input.txt' was not found.\")\n"
#     211       ],
#     212       "metadata": {
#     213         "id": "WE6hWE5o77I4",
#     214         "outputId": "0aeeca54-6618-4cbc-eea0-161c758570cc",
#     215         "colab": {
#     216           "base_uri": "https://localhost:8080/"
#     217         }
#     218       },
#     219       "execution_count": null,
#     220       "outputs": [
#     221         {
#     222           "output_type": "stream",
#     223           "name": "stdout",
#     224           "text": [
#     225             "Number of safe reports (Part 1): 442\n",
#     226             "Number of safe reports (Part 2): 493\n"
#     227           ]
#     228         }
#     229       ]
#     230     },
#     231     {
#     232       "cell_type": "markdown",
#     233       "source": [
#     234         "You wrote two functions to analyze safety reports:\n",
#     235         "\n",
#     236         "1. `is_report_safe(report)`: Checks if a report is safe based on two conditions:\n",
#     237         "    - The levels are either strictly increasing or strictly decreasing.\n",
#     238         "    - The difference between adjacent levels is between 1 and 3.\n",
#     239         "\n",
#     240         "2. `is_report_safe_with_dampener(report)`: Checks if a report can be made safe by removing at most one level (Problem Dampener).\n",
#     241         "\n",
#     242         "In `analyze_safety_reports(input_data, with_dampener=False)`, you read the input data, split it into reports, and count how many reports are safe. If `with_dampener` is `True`, it considers reports that can be made safe by removing a level.\n",
#     243         "\n",
#     244         "The solution also handles missing files using a `try-except` block to avoid errors and prints the number of safe reports for both parts of the puzzle.\n"
#     245       ],
#     246       "metadata": {
#     247         "id": "snFm22WHQjJC"
#     248       }
#     249     }
#     250   ],
#     251   "metadata": {
#     252     "colab": {
#     253       "provenance": []
#     254     },
#     255     "kernelspec": {
#     256       "display_name": "Python 3",
#     257       "name": "python3"
#     258     }
#     259   },
#     260   "nbformat": 4,
#     261   "nbformat_minor": 0
#     262 }
#
# NameError: name 'null' is not defined
