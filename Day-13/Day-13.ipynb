# %% [markdown]
# ## 13 Days of Coding: Claw Contraption Challenge 🕹️
#
# ### Problem Overview:
# The challenge involves calculating the minimum number of tokens required to win prizes from claw machines, where each machine has two buttons (A and B) with different costs and movements. The goal is to determine the fewest tokens needed to win as many prizes as possible.
#
# ### Part 1: Calculating the Fewest Tokens to Win Prizes
#
# The task is to find the optimal combination of button presses (A and B) to reach the prize's location in a claw machine.
#
# - **Button A** moves the claw by specific amounts on both the X and Y axes.
# - **Button B** moves the claw differently.
# - The objective is to find the least expensive combination of presses to match the prize location.
# ---

# %%
import math

def parse_input(file_path):
    with open(file_path, "r") as file:
        data = file.read().strip().split("\n\n")

    machines = []
    for block in data:
        lines = block.split("\n")
        button_a = tuple(map(int, lines[0].split("X+")[1].split(", Y+")))
        button_b = tuple(map(int, lines[1].split("X+")[1].split(", Y+")))
        prize = tuple(map(int, lines[2].split("X=")[1].split(", Y=")))
        machines.append((button_a, button_b, prize))

    return machines

def solve_claw_machine(button_a, button_b, prize):
    a, c = button_a
    b, d = button_b
    X, Y = prize

    min_cost = float('inf')
    best_na, best_nb = None, None

    # Iterate over possible n_A values
    for n_A in range(101):
        rem_x = X - n_A * a
        rem_y = Y - n_A * c

        if rem_x % b == 0 and rem_y % d == 0:
            n_B_x = rem_x // b
            n_B_y = rem_y // d

            if n_B_x == n_B_y and n_B_x >= 0:
                cost = 3 * n_A + n_B_x
                if cost < min_cost:
                    min_cost = cost
                    best_na, best_nb = n_A, n_B_x

    return min_cost if best_na is not None else None

def main(file_path):
    machines = parse_input(file_path)
    total_cost = 0
    prizes_won = 0

    for button_a, button_b, prize in machines:
        result = solve_claw_machine(button_a, button_b, prize)
        if result is not None:
            total_cost += result
            prizes_won += 1

    print(f"Prizes Won: {prizes_won}")
    print(f"Minimum Tokens Spent: {total_cost}")

# Example usage
main("input.txt")
# Out:
# Prizes Won: 178
# Minimum Tokens Spent: 37297

# %% [markdown]
# #### Key Points:
# - Each button has a defined movement on both axes.
# - The prize has a specific X and Y coordinate that the claw must reach.
# - You must minimize the number of tokens spent, considering each button press costs a specific amount (3 tokens for A, 1 token for B).
#
# **Example Input:**
# - Button A: X+94, Y+34
# - Button B: X+22, Y+67
# - Prize: X=8400, Y=5400
#
# **Example Solution:**
# - Use a combination of presses for A and B to reach the prize with the fewest tokens.
#
# **Total tokens for winning all possible prizes: 37,297**
#
# ---

# %% [markdown]
# ### Part 2: Adjusting Prize Locations with a Shift
#
# In Part 2, the prize locations are shifted by a large amount (10^13 units) on both the X and Y axes. The challenge is to adapt the solution to account for this shift and recalculate the minimum tokens needed to win the prizes.
#
# - The positions of all prizes are increased by 10^13 on both axes.
# - The task is to find the optimal button presses to win prizes with the updated prize locations.
#
# ---

# %%
def extended_gcd(a, b):
    if a == 0:
        return b, 0, 1
    gcd, x1, y1 = extended_gcd(b % a, a)
    x = y1 - (b // a) * x1
    y = x1
    return gcd, x, y

def find_solution(a1, a2, b1, b2, target_x, target_y):
    print(f"\nSolving for equations:")


    # Calculate determinant
    det = a1 * b2 - a2 * b1

    if det == 0:
        print("No solution - equations are dependent")
        return None

    # Using Cramer's rule
    n = (target_x * b2 - target_y * b1) / det
    m = (a1 * target_y - a2 * target_x) / det

    # Check if solution is integer and non-negative
    if n != int(n) or m != int(m) or n < 0 or m < 0:
        print(f"No valid solution: A={n}, B={m}")
        return None

    n = int(n)
    m = int(m)

    # Verify solution
    if (a1 * n + b1 * m == target_x) and (a2 * n + b2 * m == target_y):
        print(f"Found solution: A={n}, B={m}")
        return (n, m)

    return None

def solve_claw_machines_part2(input_data):
    total_tokens = 0
    possible_prizes = 0
    OFFSET = 10000000000000

    lines = input_data.strip().split('\n')

    for i in range(0, len(lines), 4):
        if i + 2 >= len(lines):
            break


        # Parse input
        a_line = lines[i].strip()
        ax = int(a_line[a_line.find('X+')+2:a_line.find(',')])
        ay = int(a_line[a_line.find('Y+')+2:])

        b_line = lines[i+1].strip()
        bx = int(b_line[b_line.find('X+')+2:b_line.find(',')])
        by = int(b_line[b_line.find('Y+')+2:])

        p_line = lines[i+2].strip()
        px = int(p_line[p_line.find('X=')+2:p_line.find(',')]) + OFFSET
        py = int(p_line[p_line.find('Y=')+2:]) + OFFSET


        # Find solution
        solution = find_solution(ax, ay, bx, by, px, py)

        if solution:
            n, m = solution
            tokens = 3 * n + m
            total_tokens += tokens
            possible_prizes += 1
            print(f"Tokens needed: {tokens}")
        else:
            print("No solution found")

    return total_tokens, possible_prizes

# Function to read input from file and process it
def read_input_file(file_path):
    with open(file_path, 'r') as file:
        input_data = file.read()
    return input_data

# Sample usage
input_file_path = 'input.txt'  # Path to the input file
input_data = read_input_file(input_file_path)
total_tokens, possible_prizes = solve_claw_machines_part2(input_data)
print(f"Total tokens needed: {total_tokens}")
# Out:
# Solving for equations:
# No valid solution: A=78223568103.03734, B=75700227135.6813
# No solution found
#
# Solving for equations:
# No valid solution: A=121867490613.5606, B=72090628267.33162
# No solution found
#
# Solving for equations:
# No valid solution: A=51369863062.69863, B=239726027436.26028
# No solution found
#
# Solving for equations:
# No valid solution: A=344370860932.15234, B=92715231804.07947
# No solution found
#
# Solving for equations:
# Found solution: A=133604415069, B=142317746093
# Tokens needed: 543130991300
#
# Solving for equations:
# Found solution: A=145631067952, B=104752171922
# Tokens needed: 541645375778
#
# Solving for equations:
# No valid solution: A=32399157625.90183, B=131216588462.70241
# No solution found
#
# Solving for equations:
# Found solution: A=113065326771, B=125628140884
# Tokens needed: 464824121197
#
# Solving for equations:
# No valid solution: A=67493615529.80701, B=76614374412.94308
# No solution found
#
# Solving for equations:
# Found solution: A=103459973069, B=101763907738
# Tokens needed: 412143826945
#
# Solving for equations:
# Found solution: A=109447004606, B=167050691572
# Tokens needed: 495391705390
#
# Solving for equations:
# Found solution: A=176245211283, B=122605363891
# Tokens needed: 651340997740
#
# Solving for equations:
# No valid solution: A=10928961778.63388, B=117486338859.81421
# No solution found
#
# Solving for equations:
# Found solution: A=134831460709, B=112359550668
# Tokens needed: 516853932795
#
# Solving for equations:
# No valid solution: A=64620355435.954765, B=197899838501.11148
# No solution found
#
# Solving for equations:
# No valid solution: A=23228803758.608593, B=104529616738.73868
# No solution found
#
# Solving for equations:
# Found solution: A=178890876674, B=101371496738
# Tokens needed: 638044126760
#
# Solving for equations:
# Found solution: A=327868852592, B=122950820031
# Tokens needed: 1106557377807
#
# Solving for equations:
# Found solution: A=170863309472, B=116906474865
# Tokens needed: 629496403281
#
# Solving for equations:
# Found solution: A=105042017084, B=168067226938
# Tokens needed: 483193278190
#
# Solving for equations:
# No valid solution: A=178092217672.05222, B=17077335963.594048
# No solution found
#
# Solving for equations:
# No valid solution: A=140357273062.69485, B=14582573856.279985
# No solution found
#
# Solving for equations:
# No valid solution: A=145882352982.17648, B=98823529498.76471
# No solution found
#
# Solving for equations:
# No valid solution: A=221474628634.38885, B=28034763203.25175
# No solution found
#
# Solving for equations:
# No valid solution: A=135537190133.64462, B=89256198394.10744
# No solution found
#
# Solving for equations:
# Found solution: A=179047619238, B=121904762054
# Tokens needed: 659047619768
#
# Solving for equations:
# No valid solution: A=86956521833.13043, B=86956521831.13043
# No solution found
#
# Solving for equations:
# No valid solution: A=92367525594.60574, B=51045211552.01896
# No solution found
#
# Solving for equations:
# No valid solution: A=98197471164.82701, B=91471616971.3457
# No solution found
#
# Solving for equations:
# Found solution: A=126582278443, B=107829348683
# Tokens needed: 487576184012
#
# Solving for equations:
# No valid solution: A=152439024479.2439, B=115176151860.51761
# No solution found
#
# Solving for equations:
# Found solution: A=260303688017, B=108459869818
# Tokens needed: 889370933869
#
# Solving for equations:
# No valid solution: A=34722222283.22222, B=123106060664.06061
# No solution found
#
# Solving for equations:
# Found solution: A=120129870068, B=100649351029
# Tokens needed: 461038961233
#
# Solving for equations:
# Found solution: A=119601329060, B=122923588242
# Tokens needed: 481727575422
#
# Solving for equations:
# Found solution: A=105177993725, B=118662351785
# Tokens needed: 434196332960
#
# Solving for equations:
# Found solution: A=141643059567, B=226628895196
# Tokens needed: 651558073897
#
# Solving for equations:
# Found solution: A=115748860058, B=133286566408
# Tokens needed: 480533146582
#
# Solving for equations:
# No valid solution: A=132850241629.89372, B=24154589388.980675
# No solution found
#
# Solving for equations:
# No valid solution: A=280059746105.1636, B=29873039676.777447
# No solution found
#
# Solving for equations:
# No valid solution: A=76923076948.07692, B=76923076930.07692
# No solution found
#
# Solving for equations:
# No valid solution: A=22288261533.601784, B=408618127878.0327
# No solution found
#
# Solving for equations:
# No valid solution: A=33540967939.502155, B=141351221858.5448
# No solution found
#
# Solving for equations:
# No valid solution: A=104703608273.42268, B=59600515516.91753
# No solution found
#
# Solving for equations:
# Found solution: A=103092783540, B=271790065676
# Tokens needed: 581068416296
#
# Solving for equations:
# Found solution: A=133281066454, B=113680909481
# Tokens needed: 513524108843
#
# Solving for equations:
# Found solution: A=331050228897, B=114155251079
# Tokens needed: 1107305937770
#
# Solving for equations:
# Found solution: A=197368421429, B=131578947549
# Tokens needed: 723684211836
#
# Solving for equations:
# No valid solution: A=276035131767.04016, B=81555834416.92096
# No solution found
#
# Solving for equations:
# No valid solution: A=105509964879.01172, B=80109417828.30519
# No solution found
#
# Solving for equations:
# No valid solution: A=151964418108.4722, B=74128984499.91327
# No solution found
#
# Solving for equations:
# Found solution: A=105540897192, B=329815303861
# Tokens needed: 646437995437
#
# Solving for equations:
# No valid solution: A=94795898684.42677, B=77384407099.98103
# No solution found
#
# Solving for equations:
# Found solution: A=145598941411, B=112508272651
# Tokens needed: 549305096884
#
# Solving for equations:
# Found solution: A=194410692768, B=133657351263
# Tokens needed: 716889429567
#
# Solving for equations:
# Found solution: A=113488372037, B=104186046716
# Tokens needed: 444651162827
#
# Solving for equations:
# No valid solution: A=119205298076.24503, B=86092715320.78809
# No solution found
#
# Solving for equations:
# No valid solution: A=89605734818.02509, B=93445980582.75473
# No solution found
#
# Solving for equations:
# Found solution: A=149031296636, B=134128167056
# Tokens needed: 581222056964
#
# Solving for equations:
# Found solution: A=103265420156, B=114429249350
# Tokens needed: 424225509818
#
# Solving for equations:
# Found solution: A=122799836589, B=118706508149
# Tokens needed: 487106017916
#
# Solving for equations:
# Found solution: A=130597015022, B=143034825861
# Tokens needed: 534825870927
#
# Solving for equations:
# Found solution: A=152505446897, B=117647058791
# Tokens needed: 575163399482
#
# Solving for equations:
# No valid solution: A=239520958163.83234, B=6653360010.773121
# No solution found
#
# Solving for equations:
# No valid solution: A=122329742638.7955, B=89465035628.43254
# No solution found
#
# Solving for equations:
# Found solution: A=134278254564, B=115628496952
# Tokens needed: 518463260644
#
# Solving for equations:
# No valid solution: A=191011235964.05618, B=56179775293.89888
# No solution found
#
# Solving for equations:
# No valid solution: A=140203294820.42728, B=143708377168.86295
# No solution found
#
# Solving for equations:
# No valid solution: A=19120458982.013386, B=325047801189.22754
# No solution found
#
# Solving for equations:
# Found solution: A=141329259271, B=110771581292
# Tokens needed: 534759359105
#
# Solving for equations:
# Found solution: A=134228187890, B=113802159449
# Tokens needed: 516486723119
#
# Solving for equations:
# Found solution: A=308123250025, B=105042016762
# Tokens needed: 1029411766837
#
# Solving for equations:
# No valid solution: A=99009901068.09901, B=71507150750.0715
# No solution found
#
# Solving for equations:
# No valid solution: A=152046783720.731, B=70175438613.49123
# No solution found
#
# Solving for equations:
# Found solution: A=187861271907, B=108381502881
# Tokens needed: 671965318602
#
# Solving for equations:
# Found solution: A=139935414676, B=215285252649
# Tokens needed: 635091496677
#
# Solving for equations:
# No valid solution: A=90160721379.77028, B=98000784033.27205
# No solution found
#
# Solving for equations:
# Found solution: A=135895032913, B=112464854976
# Tokens needed: 520149953715
#
# Solving for equations:
# No valid solution: A=248738284070.3302, B=3604902715.627974
# No solution found
#
# Solving for equations:
# No valid solution: A=133670520293.21387, B=-14450867000.02312
# No solution found
#
# Solving for equations:
# No valid solution: A=82590023171.20648, B=145358440781.3634
# No solution found
#
# Solving for equations:
# Found solution: A=131868132181, B=139194138876
# Tokens needed: 534798535419
#
# Solving for equations:
# No valid solution: A=87260035002.01396, B=191972076864.83072
# No solution found
#
# Solving for equations:
# Found solution: A=130164119963, B=158460667947
# Tokens needed: 548953027836
#
# Solving for equations:
# No valid solution: A=108001963694.06677, B=24545900853.560627
# No solution found
#
# Solving for equations:
# No valid solution: A=104982502974.18063, B=66655557479.098816
# No solution found
#
# Solving for equations:
# No valid solution: A=71551230769.16771, B=151688609049.07556
# No solution found
#
# Solving for equations:
# Found solution: A=130775937423, B=126416739213
# Tokens needed: 518744551482
#
# Solving for equations:
# Found solution: A=107374392163, B=103322528607
# Tokens needed: 425445705096
#
# Solving for equations:
# No valid solution: A=49375544647.21232, B=90037757795.38716
# No solution found
#
# Solving for equations:
# Found solution: A=208439247617, B=132180986519
# Tokens needed: 757498729370
#
# Solving for equations:
# No valid solution: A=134408602177.53763, B=71684587879.62007
# No solution found
#
# Solving for equations:
# Found solution: A=109070034740, B=172215843636
# Tokens needed: 499425947856
#
# Solving for equations:
# No valid solution: A=6846970261.679562, B=201985621441.54706
# No solution found
#
# Solving for equations:
# No valid solution: A=40241448703.152916, B=409121395048.888
# No solution found
#
# Solving for equations:
# Found solution: A=119047618911, B=119047619367
# Tokens needed: 476190476100
#
# Solving for equations:
# Found solution: A=126329787262, B=179521276976
# Tokens needed: 558510638762
#
# Solving for equations:
# Found solution: A=176848875124, B=144694533526
# Tokens needed: 675241158898
#
# Solving for equations:
# No valid solution: A=110017371180.86798, B=75275043477.90967
# No solution found
#
# Solving for equations:
# Found solution: A=107287449598, B=125506072844
# Tokens needed: 447368421638
#
# Solving for equations:
# Found solution: A=203426124227, B=171306210191
# Tokens needed: 781584582872
#
# Solving for equations:
# No valid solution: A=70364238500.59602, B=82781456980.64238
# No solution found
#
# Solving for equations:
# No valid solution: A=199928597006.66797, B=-17850767496.00607
# No solution found
#
# Solving for equations:
# No valid solution: A=77.0, B=333333333343.3333
# No solution found
#
# Solving for equations:
# No valid solution: A=132908027673.86975, B=116959064420.48538
# No solution found
#
# Solving for equations:
# No valid solution: A=25316455761.20253, B=267631103121.14105
# No solution found
#
# Solving for equations:
# Found solution: A=150829562927, B=135746606384
# Tokens needed: 588235295165
#
# Solving for equations:
# No valid solution: A=40211640237.64021, B=131216931233.93121
# No solution found
#
# Solving for equations:
# No valid solution: A=180608365097.0114, B=28517110339.159695
# No solution found
#
# Solving for equations:
# No valid solution: A=476190476258.4762, B=22.0
# No solution found
#
# Solving for equations:
# No valid solution: A=133719634506.6657, B=37887229777.90528
# No solution found
#
# Solving for equations:
# No valid solution: A=178389398666.88483, B=112130479201.95616
# No solution found
#
# Solving for equations:
# No valid solution: A=118126273000.42363, B=126272912493.62526
# No solution found
#
# Solving for equations:
# No valid solution: A=68935803560.95993, B=150797070249.34985
# No solution found
#
# Solving for equations:
# No valid solution: A=75456711728.93327, B=194598888020.35425
# No solution found
#
# Solving for equations:
# No valid solution: A=154958677769.9504, B=41322314056.58678
# No solution found
#
# Solving for equations:
# Found solution: A=138623327334, B=167304015316
# Tokens needed: 583173997318
#
# Solving for equations:
# No valid solution: A=209071580491.40466, B=53153791690.13678
# No solution found
#
# Solving for equations:
# Found solution: A=142231947696, B=109409190416
# Tokens needed: 536105033504
#
# Solving for equations:
# Found solution: A=102040816397, B=155279503215
# Tokens needed: 461401952406
#
# Solving for equations:
# Found solution: A=112781955220, B=187969924973
# Tokens needed: 526315790633
#
# Solving for equations:
# Found solution: A=168650793464, B=218253968822
# Tokens needed: 724206349214
#
# Solving for equations:
# Found solution: A=220137134923, B=101046553619
# Tokens needed: 761457958388
#
# Solving for equations:
# No valid solution: A=148637489717.95212, B=140379851369.5103
# No solution found
#
# Solving for equations:
# Found solution: A=106609808290, B=223880597267
# Tokens needed: 543710022137
#
# Solving for equations:
# No valid solution: A=75217735630.27711, B=142517814772.84085
# No solution found
#
# Solving for equations:
# No valid solution: A=105846774269.54839, B=100806451705.90323
# No solution found
#
# Solving for equations:
# Found solution: A=104408352744, B=301624130406
# Tokens needed: 614849188638
#
# Solving for equations:
# No valid solution: A=72732263001.99203, B=105667627359.46013
# No solution found
#
# Solving for equations:
# No valid solution: A=73821692244.32936, B=113571834207.12209
# No solution found
#
# Solving for equations:
# No valid solution: A=77720207336.88602, B=414507772098.7254
# No solution found
#
# Solving for equations:
# Found solution: A=121681416007, B=210176991370
# Tokens needed: 575221239391
#
# Solving for equations:
# Found solution: A=118946474288, B=195412064486
# Tokens needed: 552251487350
#
# Solving for equations:
# Found solution: A=130753138066, B=115062761778
# Tokens needed: 507322175976
#
# Solving for equations:
# Found solution: A=237027546496, B=121716848545
# Tokens needed: 832799488033
#
# Solving for equations:
# Found solution: A=179257362418, B=243277849259
# Tokens needed: 781049936513
#
# Solving for equations:
# Found solution: A=113993710848, B=176886792814
# Tokens needed: 518867925358
#
# Solving for equations:
# Found solution: A=201005025399, B=150753768675
# Tokens needed: 753768844872
#
# Solving for equations:
# Found solution: A=104208416983, B=118236472933
# Tokens needed: 430861723882
#
# Solving for equations:
# Found solution: A=110782865706, B=192023633791
# Tokens needed: 524372230909
#
# Solving for equations:
# Found solution: A=108695652395, B=108695652217
# Tokens needed: 434782609402
#
# Solving for equations:
# Found solution: A=105263158114, B=105263157902
# Tokens needed: 421052632244
#
# Solving for equations:
# Found solution: A=212038304044, B=157318741683
# Tokens needed: 793433653815
#
# Solving for equations:
# No valid solution: A=64239828723.79015, B=72475704216.353
# No solution found
#
# Solving for equations:
# No valid solution: A=400843881868.5401, B=21097046495.50211
# No solution found
#
# Solving for equations:
# No valid solution: A=31746031832.031746, B=197530864256.53085
# No solution found
#
# Solving for equations:
# Found solution: A=118209255715, B=103118712400
# Tokens needed: 457746479545
#
# Solving for equations:
# No valid solution: A=25445292716.86514, B=133587786320.54199
# No solution found
#
# Solving for equations:
# Found solution: A=124481327798, B=112625963301
# Tokens needed: 486069946695
#
# Solving for equations:
# Found solution: A=125373134312, B=137313432923
# Tokens needed: 513432835859
#
# Solving for equations:
# No valid solution: A=90750436336.17451, B=164048865648.54623
# No solution found
#
# Solving for equations:
# No valid solution: A=39991580760.84845, B=145232582662.1865
# No solution found
#
# Solving for equations:
# Found solution: A=130890052504, B=104712041776
# Tokens needed: 497382199288
#
# Solving for equations:
# Found solution: A=159763313930, B=100591715887
# Tokens needed: 579881657677
#
# Solving for equations:
# No valid solution: A=153465346593.65347, B=14851485209.51485
# No solution found
#
# Solving for equations:
# No valid solution: A=115681234010.16196, B=17673521887.899742
# No solution found
#
# Solving for equations:
# Found solution: A=215053763365, B=107526881941
# Tokens needed: 752688172036
#
# Solving for equations:
# No valid solution: A=297085201881.722, B=56053811735.192825
# No solution found
#
# Solving for equations:
# No valid solution: A=261194029928.74628, B=60634328388.208954
# No solution found
#
# Solving for equations:
# No valid solution: A=165816326629.61224, B=-25510204000.632652
# No solution found
#
# Solving for equations:
# No valid solution: A=88300220782.55188, B=154525386406.4658
# No solution found
#
# Solving for equations:
# Found solution: A=112855740746, B=107948969712
# Tokens needed: 446516191950
#
# Solving for equations:
# No valid solution: A=32119914370.895077, B=139186295524.212
# No solution found
#
# Solving for equations:
# No valid solution: A=53070507998.576195, B=348749052361.35785
# No solution found
#
# Solving for equations:
# Found solution: A=132515337706, B=100613497023
# Tokens needed: 498159510141
#
# Solving for equations:
# Found solution: A=165745856347, B=110497237636
# Tokens needed: 607734806677
#
# Solving for equations:
# Found solution: A=118806143420, B=104317588986
# Tokens needed: 460736019246
#
# Solving for equations:
# No valid solution: A=185419300485.54825, B=63211125172.02781
# No solution found
#
# Solving for equations:
# No valid solution: A=36835982956.12369, B=112446684778.53548
# No solution found
#
# Solving for equations:
# No valid solution: A=187110187183.1871, B=25410025457.02541
# No solution found
#
# Solving for equations:
# Found solution: A=161023947228, B=115606936494
# Tokens needed: 598678778178
#
# Solving for equations:
# No valid solution: A=146294513986.72665, B=28873917302.103947
# No solution found
#
# Solving for equations:
# Found solution: A=126796280802, B=118343195391
# Tokens needed: 498732037797
#
# Solving for equations:
# No valid solution: A=133333333388.33333, B=125490196177.43137
# No solution found
#
# Solving for equations:
# Found solution: A=117508812983, B=317273796483
# Tokens needed: 669800235432
#
# Solving for equations:
# No valid solution: A=133770822911.75922, B=73195355915.86826
# No solution found
#
# Solving for equations:
# No valid solution: A=102756892288.57645, B=65162907347.170425
# No solution found
#
# Solving for equations:
# No valid solution: A=121885157195.4247, B=43336944820.39545
# No solution found
#
# Solving for equations:
# Found solution: A=168067227145, B=221543163093
# Tokens needed: 725744844528
#
# Solving for equations:
# Found solution: A=200573066538, B=143266475617
# Tokens needed: 744985675231
#
# Solving for equations:
# No valid solution: A=21561017726.034496, B=103492884870.16559
# No solution found
#
# Solving for equations:
# No valid solution: A=52910052945.05291, B=123456790168.45679
# No solution found
#
# Solving for equations:
# Found solution: A=146471371550, B=186418109217
# Tokens needed: 625832223867
#
# Solving for equations:
# Found solution: A=101321585950, B=110132158731
# Tokens needed: 414096916581
#
# Solving for equations:
# Found solution: A=130769231066, B=184615384522
# Tokens needed: 576923077720
#
# Solving for equations:
# No valid solution: A=69166363331.4241, B=98289042615.91846
# No solution found
#
# Solving for equations:
# Found solution: A=158192090627, B=104519774120
# Tokens needed: 579096046001
#
# Solving for equations:
# Found solution: A=107933081425, B=167296276619
# Tokens needed: 491095520894
#
# Solving for equations:
# Found solution: A=121239335702, B=112258643855
# Tokens needed: 475976650961
#
# Solving for equations:
# Found solution: A=109199205906, B=105890139156
# Tokens needed: 433487756874
#
# Solving for equations:
# No valid solution: A=113098910143.77504, B=84310096738.15958
# No solution found
#
# Solving for equations:
# No valid solution: A=48334421954.44024, B=90137165330.46964
# No solution found
#
# Solving for equations:
# No valid solution: A=96680631710.79343, B=132130196675.95102
# No solution found
#
# Solving for equations:
# No valid solution: A=51813471533.590675, B=207253886087.3627
# No solution found
#
# Solving for equations:
# No valid solution: A=92412451372.8677, B=155642023390.3035
# No solution found
#
# Solving for equations:
# No valid solution: A=127834056959.33478, B=41003376840.67342
# No solution found
#
# Solving for equations:
# No valid solution: A=165137614719.89908, B=36697247752.42202
# No solution found
#
# Solving for equations:
# Found solution: A=105960264867, B=145695364543
# Tokens needed: 463576159144
#
# Solving for equations:
# No valid solution: A=86242299847.6612, B=88295687914.01027
# No solution found
#
# Solving for equations:
# No valid solution: A=93797276944.25266, B=68078668691.81241
# No solution found
#
# Solving for equations:
# No valid solution: A=301794453515.34094, B=69331158278.17291
# No solution found
#
# Solving for equations:
# Found solution: A=195694716414, B=225048923880
# Tokens needed: 812133073122
#
# Solving for equations:
# Found solution: A=343642611338, B=103092783918
# Tokens needed: 1134020617932
#
# Solving for equations:
# No valid solution: A=34647033431.7696, B=106106539665.54439
# No solution found
#
# Solving for equations:
# Found solution: A=104129264092, B=147217235150
# Tokens needed: 459605027426
#
# Solving for equations:
# Found solution: A=280898876383, B=168539325951
# Tokens needed: 1011235955100
#
# Solving for equations:
# No valid solution: A=181268882218.2266, B=50352467348.89627
# No solution found
#
# Solving for equations:
# Found solution: A=135214580012, B=176366842860
# Tokens needed: 582010582896
#
# Solving for equations:
# No valid solution: A=64565718708.94005, B=81475787881.49577
# No solution found
#
# Solving for equations:
# No valid solution: A=123579828605.81842, B=77735698697.6761
# No solution found
#
# Solving for equations:
# No valid solution: A=108577633091.60043, B=103148751400.22041
# No solution found
#
# Solving for equations:
# Found solution: A=105719707184, B=124695039644
# Tokens needed: 441854161196
#
# Solving for equations:
# No valid solution: A=151436031426.59268, B=93994778084.88512
# No solution found
#
# Solving for equations:
# No valid solution: A=43804755972.93117, B=150187734682.33542
# No solution found
#
# Solving for equations:
# No valid solution: A=99778270570.97783, B=88691796080.86919
# No solution found
#
# Solving for equations:
# No valid solution: A=101816180553.33627, B=118326912534.12053
# No solution found
#
# Solving for equations:
# No valid solution: A=57442967393.57, B=95191203117.85886
# No solution found
#
# Solving for equations:
# No valid solution: A=148257968949.82654, B=3706449296.6456633
# No solution found
#
# Solving for equations:
# Found solution: A=164705882355, B=188235294355
# Tokens needed: 682352941420
#
# Solving for equations:
# No valid solution: A=100958247832.49623, B=37645448387.06639
# No solution found
#
# Solving for equations:
# No valid solution: A=107962213308.37112, B=79284750422.38191
# No solution found
#
# Solving for equations:
# No valid solution: A=236734693902.55103, B=16326530650.244898
# No solution found
#
# Solving for equations:
# No valid solution: A=28647431989.34909, B=124820953617.23532
# No solution found
#
# Solving for equations:
# No valid solution: A=144927536259.88406, B=54347826089.95652
# No solution found
#
# Solving for equations:
# Found solution: A=207228915753, B=101204819298
# Tokens needed: 722891566557
#
# Solving for equations:
# Found solution: A=192893401965, B=142131979432
# Tokens needed: 720812185327
#
# Solving for equations:
# Found solution: A=140562249125, B=120481927686
# Tokens needed: 542168675061
#
# Solving for equations:
# No valid solution: A=216049382726.04938, B=10288065853.621399
# No solution found
#
# Solving for equations:
# No valid solution: A=91984231314.63863, B=223390275979.69382
# No solution found
#
# Solving for equations:
# Found solution: A=139431120988, B=217512549251
# Tokens needed: 635805912215
#
# Solving for equations:
# No valid solution: A=406976744189.0465, B=58139534908.72093
# No solution found
#
# Solving for equations:
# No valid solution: A=83472454118.15025, B=108514190327.19533
# No solution found
#
# Solving for equations:
# No valid solution: A=68127962174.30806, B=216232227506.15167
# No solution found
#
# Solving for equations:
# No valid solution: A=106621773306.43996, B=252525252556.25253
# No solution found
#
# Solving for equations:
# No valid solution: A=523479599778.0708, B=23094688314.709007
# No solution found
#
# Solving for equations:
# No valid solution: A=21645021740.021645, B=108225108304.10823
# No solution found
#
# Solving for equations:
# Found solution: A=181159420451, B=139751552926
# Tokens needed: 683229814279
#
# Solving for equations:
# No valid solution: A=117554859003.16928, B=113636363666.36363
# No solution found
#
# Solving for equations:
# No valid solution: A=134619699382.33812, B=42629571520.62374
# No solution found
#
# Solving for equations:
# Found solution: A=152718387284, B=134392181008
# Tokens needed: 592547342860
#
# Solving for equations:
# Found solution: A=131233595922, B=104986876733
# Tokens needed: 498687664499
#
# Solving for equations:
# No valid solution: A=33898305153.74576, B=135593220342.98305
# No solution found
#
# Solving for equations:
# No valid solution: A=191938579740.51056, B=105566218898.9808
# No solution found
#
# Solving for equations:
# Found solution: A=164810690756, B=120267260721
# Tokens needed: 614699332989
#
# Solving for equations:
# No valid solution: A=137589433164.5355, B=42194092897.00422
# No solution found
#
# Solving for equations:
# No valid solution: A=104529616816.73868, B=92915214904.43437
# No solution found
#
# Solving for equations:
# No valid solution: A=88268335825.65158, B=44936607323.149895
# No solution found
#
# Solving for equations:
# No valid solution: A=162601626051.26016, B=203252032564.3252
# No solution found
#
# Solving for equations:
# No valid solution: A=86972962794.88335, B=58612214126.117035
# No solution found
#
# Solving for equations:
# No valid solution: A=107050572203.85124, B=51679586641.307495
# No solution found
#
# Solving for equations:
# Found solution: A=140525838695, B=101994560346
# Tokens needed: 523572076431
#
# Solving for equations:
# Found solution: A=101707228651, B=105339629640
# Tokens needed: 410461315593
#
# Solving for equations:
# No valid solution: A=105064655176.41379, B=67349137954.034485
# No solution found
#
# Solving for equations:
# Found solution: A=152931181123, B=110450297556
# Tokens needed: 569243840925
#
# Solving for equations:
# Found solution: A=136157337614, B=105900151449
# Tokens needed: 514372164291
#
# Solving for equations:
# Found solution: A=118453865659, B=124688279243
# Tokens needed: 480049876220
#
# Solving for equations:
# No valid solution: A=56136769595.07757, B=108446032220.05894
# No solution found
#
# Solving for equations:
# No valid solution: A=42906178504.702515, B=105835240355.59955
# No solution found
#
# Solving for equations:
# Found solution: A=102040816458, B=102040816377
# Tokens needed: 408163265751
#
# Solving for equations:
# No valid solution: A=71174377308.1993, B=154211150686.4318
# No solution found
#
# Solving for equations:
# No valid solution: A=122514561189.85881, B=-12050612485.805784
# No solution found
#
# Solving for equations:
# No valid solution: A=77582686899.94324, B=134748877112.69089
# No solution found
#
# Solving for equations:
# Found solution: A=187032419461, B=105985037212
# Tokens needed: 667082295595
#
# Solving for equations:
# No valid solution: A=101105845240.67456, B=97946287565.74724
# No solution found
#
# Solving for equations:
# No valid solution: A=90252707619.22743, B=42117930230.57281
# No solution found
#
# Solving for equations:
# No valid solution: A=71047957415.22557, B=79928952098.62877
# No solution found
#
# Solving for equations:
# No valid solution: A=52830188774.245285, B=113207547231.81133
# No solution found
#
# Solving for equations:
# No valid solution: A=98416773653.42062, B=53487377005.03295
# No solution found
#
# Solving for equations:
# No valid solution: A=44987146609.56298, B=104434447339.77121
# No solution found
#
# Solving for equations:
# No valid solution: A=49180327929.85246, B=81967213126.7541
# No solution found
#
# Solving for equations:
# Found solution: A=137221269687, B=131503716395
# Tokens needed: 543167525456
#
# Solving for equations:
# Found solution: A=103926097167, B=115473441076
# Tokens needed: 427251732577
#
# Solving for equations:
# Found solution: A=124113475170, B=121580547242
# Tokens needed: 493920972752
#
# Solving for equations:
# Found solution: A=130505709405, B=118270799625
# Tokens needed: 509787927840
#
# Solving for equations:
# Found solution: A=121268656433, B=223880597624
# Tokens needed: 587686566923
#
# Solving for equations:
# Found solution: A=119985001972, B=123734533537
# Tokens needed: 483689539453
#
# Solving for equations:
# Found solution: A=263157895441, B=126705652898
# Tokens needed: 916179339221
#
# Solving for equations:
# No valid solution: A=276981852945.085, B=47755491961.56638
# No solution found
#
# Solving for equations:
# No valid solution: A=116040955721.39932, B=83617747517.27304
# No solution found
#
# Solving for equations:
# No valid solution: A=113636363708.36363, B=132575757585.75757
# No solution found
#
# Solving for equations:
# Found solution: A=203070827452, B=138682516280
# Tokens needed: 747894998636
#
# Solving for equations:
# Found solution: A=107047279462, B=258697591357
# Tokens needed: 579839429743
#
# Solving for equations:
# No valid solution: A=127131782966.73643, B=44961240332.07752
# No solution found
#
# Solving for equations:
# Found solution: A=182648402170, B=228310502704
# Tokens needed: 776255709214
#
# Solving for equations:
# No valid solution: A=101516634085.88063, B=44031311159.59882
# No solution found
#
# Solving for equations:
# Found solution: A=102758247685, B=135208220941
# Tokens needed: 443482963996
#
# Solving for equations:
# Found solution: A=108749382338, B=143351458414
# Tokens needed: 469599605428
#
# Solving for equations:
# No valid solution: A=146750524160.01468, B=153738644383.68204
# No solution found
#
# Solving for equations:
# No valid solution: A=171350239948.33585, B=130226182388.65524
# No solution found
#
# Solving for equations:
# No valid solution: A=82324455254.81114, B=140435835390.0896
# No solution found
#
# Solving for equations:
# Found solution: A=105633803247, B=181924882590
# Tokens needed: 498826292331
#
# Solving for equations:
# No valid solution: A=77429345809.02866, B=129694154177.39798
# No solution found
#
# Solving for equations:
# No valid solution: A=92770313535.6801, B=41586692292.47729
# No solution found
#
# Solving for equations:
# Found solution: A=196891191802, B=207253886322
# Tokens needed: 797927461728
#
# Solving for equations:
# No valid solution: A=147098154637.7879, B=42792190487.24739
# No solution found
#
# Solving for equations:
# No valid solution: A=162866449598.40067, B=195439739480.6808
# No solution found
#
# Solving for equations:
# Found solution: A=283286119548, B=127478753498
# Tokens needed: 977337112142
#
# Solving for equations:
# Found solution: A=128794848653, B=101195952125
# Tokens needed: 487580498084
#
# Solving for equations:
# No valid solution: A=104253544697.5171, B=16680567190.282736
# No solution found
#
# Solving for equations:
# Found solution: A=154929577391, B=239436620309
# Tokens needed: 704225352482
#
# Solving for equations:
# Found solution: A=104821803098, B=101327742957
# Tokens needed: 415793152251
#
# Solving for equations:
# No valid solution: A=149590742376.77786, B=56449336724.29353
# No solution found
#
# Solving for equations:
# No valid solution: A=31903580333.677063, B=99255583199.55087
# No solution found
#
# Solving for equations:
# Found solution: A=108695652189, B=137681159523
# Tokens needed: 463768116090
#
# Solving for equations:
# No valid solution: A=68965517336.3793, B=141215106757.3481
# No solution found
#
# Solving for equations:
# No valid solution: A=109956017665.96281, B=33986405499.82487
# No solution found
#
# Solving for equations:
# No valid solution: A=74519919776.77873, B=87417598181.66351
# No solution found
#
# Solving for equations:
# Found solution: A=101404056163, B=257410296547
# Tokens needed: 561622465036
#
# Solving for equations:
# No valid solution: A=46511627922.976746, B=186046511707.90698
# No solution found
#
# Solving for equations:
# No valid solution: A=80982965715.0525, B=97738062031.85646
# No solution found
#
# Solving for equations:
# No valid solution: A=141198619454.27707, B=106683401406.85378
# No solution found
#
# Solving for equations:
# No valid solution: A=39215686341.5098, B=117647058853.52942
# No solution found
#
# Solving for equations:
# Found solution: A=124378109622, B=118159203814
# Tokens needed: 491293532680
#
# Solving for equations:
# Found solution: A=114613180770, B=109240687694
# Tokens needed: 453080230004
#
# Solving for equations:
# Found solution: A=129390018451, B=117067159736
# Tokens needed: 505237215089
#
# Solving for equations:
# Found solution: A=131135256833, B=153615586542
# Tokens needed: 547021357041
#
# Solving for equations:
# No valid solution: A=116959064390.48538, B=80409356806.1462
# No solution found
#
# Solving for equations:
# Found solution: A=138121547015, B=101289134543
# Tokens needed: 515653775588
#
# Solving for equations:
# No valid solution: A=102206359585.81375, B=42180402407.14536
# No solution found
#
# Solving for equations:
# Found solution: A=116991643550, B=114206128260
# Tokens needed: 465181058910
# Total tokens needed: 83197086729371

# %% [markdown]
# #### Key Points:
# - The shift introduces much larger numbers and makes the problem more complex.
# - The goal remains to minimize the tokens spent by finding the optimal button presses.
#
# **Total tokens for winning all possible prizes in Part 2: 83,197,086,729,371**
